# %%
import numpy as np
import matplotlib as plt

# %%
sales_data=np.array([
    [1, 150000, 180000, 220000, 250000],
    [2, 120000, 140000, 160000, 190000],
    [3, 200000, 230000, 260000, 300000],
    [4, 180000, 210000, 240000, 270000],
    [5, 160000, 185000, 2025000, 230000]
])


print("======= Zomato sales analysis =======")
print("\n Sales data shape: ", sales_data.shape )
print("sample data for 1st 3 restau: \n", sales_data[0:3])
# Out:
# ======= Zomato sales analysis =======
#
#  Sales data shape:  (5, 5)
# sample data for 1st 3 restau:
#  [[     1 150000 180000 220000 250000]
#  [     2 120000 140000 160000 190000]
#  [     3 200000 230000 260000 300000]]

# %%
# total sales per year

print(np.sum(sales_data, axis=0))
yeary_total=np.sum(sales_data[ :,0:],axis=0)
print(yeary_total)
# Out:
# [     15  810000  945000 2905000 1240000]
# [     15  810000  945000 2905000 1240000]

# %%
# minimum sales per restaurant

min_sales=np.min(sales_data[:,1:], axis=1)
print(min_sales)
# Out:
# [150000 120000 200000 180000 160000]

# %%
#  maximum sales per year

max_sales=np.max(sales_data[:,1:], axis=0)
print(max_sales)
# Out:
# [ 200000  230000 2025000  300000]

# %%
# average sales per year

avg_sales=np.average(sales_data[:,1:], axis=0)
print(avg_sales)
# Out:
# [162000. 189000. 581000. 248000.]

# %%
cumsum=np.cumsum(sales_data[:,1:], axis=1)
print(cumsum)


# Plot average cumulative sales
plt.figure(figsize=(10, 6))
plt.plot(np.mean(cumsum, axis=0), marker="o", linestyle="-", label="Average Sales")
plt.title("Average Cumulative Sales Across All Restaurants")
plt.xlabel("Years")
plt.ylabel("Sales")
plt.grid(True)
plt.legend()
plt.show()
# Out:
# [[100 300 600]
#  [150 400 750]
#  [120 340 660]]

# %%
vector1=np.array([1,2,3,4,5])
vector2=np.array([6,7,8,9,10])

print("vector addition: ", vector1+vector2)

print("Multiplication vector: ", vector1*vector2)
# Out:
# vector addition:  [ 7  9 11 13 15]
# Multiplication vector:  [ 6 14 24 36 50]

# %%
print("DOT product: ",np.dot(vector1,vector2))

angle=np.arccos(np.dot(vector1, vector2)/ ((np.linalg.norm(vector1)* np.linalg.norm(vector2))))

print(angle)
# Out:
# DOT product:  130
# 0.26554161733900966

# %%
restaurant_types=np.array(['biryani', 'chinese', 'pizza', 'burger', 'cafe'])
vectorized_upper=np.vectorize(str.upper)
print("Vectorized upper: ", vectorized_upper(restaurant_types))
# Out:
# Vectorized upper:  ['BIRYANI' 'CHINESE' 'PIZZA' 'BURGER' 'CAFE']

# %%
monthly_avg=sales_data[:, 1:] / 12
print("monthly  avg: \n ", monthly_avg)
# Out:
# monthly  avg:
#   [[ 8.33333333 16.66666667 25.        ]
#  [12.5        20.83333333 29.16666667]
#  [10.         18.33333333 26.66666667]]
