# %%
data = (0, 0, 5)
print(any(data))
# Out:
# True

# %%
data = (1, 2, 3)
print(all(data))
# Out:
# True

# %%
data = (1, 0, 3)
print(all(data))
# Out:
# False

# %%
letters = ('a', 'b', 'c', 'b', 'd')
print(letters.index('b'))
# Out:
# 1

# %%
letters = ('a', 'b', 'c', 'b', 'd')
print(letters.index('b', 2))
# Out:
# 3

# %%
names = ('Ajit', 'Rahul', 'Neha','abhishek')
marks = (85, 90, 95, 99)
grades = ('A', 'A+', 'A', 'A')

result = zip(names, marks, grades)
print(tuple(result))
# Out:
# (('Ajit', 85, 'A'), ('Rahul', 90, 'A+'), ('Neha', 95, 'A'), ('abhishek', 99, 'A'))
