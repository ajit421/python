# %%
nums = [10, 20, 30, 40, 50, 60]
del nums[1:4]     # deletes 20, 30, 40
print(nums)       # [10, 50, 60]
# Out:
# [10, 50, 60]

# %%
nums = [1, 2, 3]
del nums
print(nums)     # ❌ Error: NameError (list no longer exists)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 3
#       1 nums = [1, 2, 3]
#       2 del nums
# ----> 3 print(nums)     # ❌ Error: NameError (list no longer exists)
#
# NameError: name 'nums' is not defined

# %%
student = {'name': 'Ajit', 'age': 21, 'course': 'Python'}
print(len(student))
# Out:
# 3

# %%
marks = {'Math': 90, 'Science': 85, 'English': 88}
print(sorted(marks))
# Out:
# ['English', 'Math', 'Science']

# %%
student = {'name': 'Ajit', 'age': 21, 'course': 'Python'}
print(student.keys())
# Out:
# dict_keys(['name', 'age', 'course'])

# %%
age = student.pop('age')
print(age)
print(student)
# Out:
# 21
# {'name': 'Ajit', 'course': 'Python'}

# %%
last = student.popitem()
print(last)
print(student)
# Out:
# ('course', 'Python')
# {'name': 'Ajit'}

# %%
student.setdefault('grade', 'A')
print(student)
# Out:
# {'name': 'Ajit', 'grade': 'A'}

# %%
copy_student = student.copy()
print(copy_student)
# Out:
# {'name': 'Ajit', 'grade': 'A'}

# %%
student.clear()
print(student)
# Out:
# {}

# %%
person = ('Ajit', 21, ['Python', 'C++'], (5, 10))
print(person)
# Out:
# ('Ajit', 21, ['Python', 'C++'], (5, 10))

# %%
nested = ((1, 2), (3, 4), (5, 6))
print(nested)
# Out:
# ((1, 2), (3, 4), (5, 6))

# %%
t1 = (1, 2, 3)
del t1
print(t1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 3
#       1 t1 = (1, 2, 3)
#       2 del t1
# ----> 3 print(t1)
#
# NameError: name 't1' is not defined
