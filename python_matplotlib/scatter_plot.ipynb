# %%
import matplotlib.pyplot as plt

# %%
from turtle import color


team1_score=[25,47,34,38,27,40,42,18]
team2_score=[7, 22,40,29,27,10,19,31]

scoerange=[5,10,15,20,25,30,35,40]

plt.scatter(team1_score, scoerange, color='r')
plt.scatter(team2_score, scoerange, color='b')

plt.xlabel("team score")
plt.ylabel("score range")

plt.show()
