# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
student = np.array(["Ajit",  "amit", "golden", "aman"])
marks=np.array([99,71,99,66])

plt.xlabel("---------------------------------Student-----------------------------")
plt.ylabel("--------------------------marks--------------------------------")

plt.bar(student, marks)

plt.show()
