# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
arr = np.array([10, 50, 34, 67, 21, 7, 59, 62, 55, 48, 10, 76, 41])

plt.hist(arr, bins=[0,20,40,60,80])

plt.xlabel("Marks")
plt.ylabel("student")

plt.title("student marks")

plt.show()
