# %%
import matplotlib.pyplot as plt 
import numpy as np 
import pandas as pd

# %%
xpts = np.array([0, 10])
ypts = np.array([0, 125])

plt.plot(xpts, ypts)  
plt.show()  # display the figure

# %%
data = {
    "Cricket_bat": ["s6", "BDM", "SS", "GM", "KOOKABURRE", "SPARTAN"],
    "MRP": [2000, 2200, 2400, 2700, 2800, 3000],
    "Weight_Grams": [1100, 1200, 1250, 1330, 1480, 1600]

}

Data= pd.DataFrame(data)

plt.plot(Data["MRP"], Data["Weight_Grams"])

plt.grid() # Grid lines
plt.show()  # display the figure

# %%
plt.plot(Data["Weight_Grams"], Data["Cricket_bat"])
plt.show()  # display the figure
plt.

# %%
plt.plot(Data["MRP"], Data["Weight_Grams"])

plt.xlabel("---------------------------------- Bat price ----------------------------------------")
plt.ylabel("---------------------------- Weight ---------------------------")

plt.show()

# %%
plt.plot(Data["MRP"], Data["Weight_Grams"])

plt.xlabel("Bat price ( USDT )")
plt.ylabel("Bat weight ( Gram )")

plt.title("Bat price depends on the weight")
plt.show()
